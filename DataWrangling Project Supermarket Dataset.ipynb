# %%
import pandas as pd
import numpy as np

# %%
pwd
# Out:
# 'C:\\Users\\DELL\\Python INFOTECH'

# %%
df= pd.read_csv("Supermarket_Sales.csv")

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.tail(10)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 990  886-18-2897      A     Yangon        Normal  Female
# 991  602-16-6955      B   Mandalay        Normal  Female
# 992  745-74-0715      A     Yangon        Normal    Male
# 993  690-01-6631      B   Mandalay        Normal    Male
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 990      Food and beverages       56.56         5  14.1400   296.9400
# 991       Sports and travel       76.60        10  38.3000   804.3000
# 992  Electronic accessories       58.03         2   5.8030   121.8630
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %% [markdown]
# # describe

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %% [markdown]
# # indexing and slicing

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.iloc[0:5, 1:4]
# Out:
#   Branch       City Customer type
# 0      A     Yangon        Member
# 1      C  Naypyitaw        Normal
# 2      A     Yangon        Normal
# 3      A     Yangon        Member
# 4      A     Yangon        Normal

# %%
df.iloc[:,-3:]
# Out:
#      gross margin percentage  gross income  Rating
# 0                   4.761905       26.1415     9.1
# 1                   4.761905        3.8200     9.6
# 2                   4.761905       16.2155     7.4
# 3                   4.761905       23.2880     8.4
# 4                   4.761905       30.2085     5.3
# ..                       ...           ...     ...
# 995                 4.761905        2.0175     6.2
# 996                 4.761905       48.6900     4.4
# 997                 4.761905        1.5920     7.7
# 998                 4.761905        3.2910     4.1
# 999                 4.761905       30.9190     6.6
#
# [1000 rows x 3 columns]

# %%
df.loc[50:60,['Branch', 'City', 'Customer type']]
# Out:
#    Branch       City Customer type
# 50      C  Naypyitaw        Member
# 51      A     Yangon        Member
# 52      B   Mandalay        Member
# 53      C  Naypyitaw        Member
# 54      B   Mandalay        Normal
# 55      C  Naypyitaw        Normal
# 56      A     Yangon        Member
# 57      A     Yangon        Normal
# 58      A     Yangon        Member
# 59      C  Naypyitaw        Normal
# 60      C  Naypyitaw        Member

# %%
df[0:10]
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
# 6  355-53-5943      A     Yangon        Member  Female
# 7  315-22-5665      C  Naypyitaw        Normal  Female
# 8  665-32-9167      A     Yangon        Member  Female
# 9  692-92-5582      B   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# ...

# %%
df[['Gender','Product line','Unit price']]
# Out:
#      Gender            Product line  Unit price
# 0    Female       Health and beauty       74.69
# 1    Female  Electronic accessories       15.28
# 2      Male      Home and lifestyle       46.33
# 3      Male       Health and beauty       58.22
# 4      Male       Sports and travel       86.31
# ..      ...                     ...         ...
# 995    Male       Health and beauty       40.35
# 996  Female      Home and lifestyle       97.38
# 997    Male      Food and beverages       31.84
# 998    Male      Home and lifestyle       65.82
# 999  Female     Fashion accessories       88.34
#
# [1000 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df['Gender'] == 'Female'
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996     True
# 997    False
# 998    False
# 999     True
# Name: Gender, Length: 1000, dtype: bool

# %%
df['Gender'] == 'Male'
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 995     True
# 996    False
# 997     True
# 998     True
# 999    False
# Name: Gender, Length: 1000, dtype: bool

# %%
# Boolean indexing
Female = df[df['Gender'] == 'Female']
Female.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 6  355-53-5943      A     Yangon        Member  Female
# 7  315-22-5665      C  Naypyitaw        Normal  Female
# 8  665-32-9167      A     Yangon        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 6  Electronic accessories       68.84         6  20.6520  433.6920  2/25/2019
# 7      Home and lifestyle       73.56        10  36.7800  772.3800  2/24/2019
# 8       Health and beauty       36.26         2   3.6260   76.1460  1/10/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
Male = df[df['Gender'] == 'Male']
Male.head()
# Out:
#      Invoice ID Branch       City Customer type Gender  \
# 2   631-41-3108      A     Yangon        Normal   Male
# 3   123-19-1176      A     Yangon        Member   Male
# 4   373-73-7910      A     Yangon        Normal   Male
# 5   699-14-3026      C  Naypyitaw        Normal   Male
# 11  529-56-3974      B   Mandalay        Member   Male
#
#               Product line  Unit price  Quantity   Tax 5%     Total  \
# 2       Home and lifestyle       46.33         7  16.2155  340.5255
# 3        Health and beauty       58.22         8  23.2880  489.0480
# 4        Sports and travel       86.31         7  30.2085  634.3785
# 5   Electronic accessories       85.39         7  29.8865  627.6165
# 11  Electronic accessories       25.51         4   5.1020  107.1420
#
#          Date   Time      Payment    cogs  gross margin percentage  \
# 2    3/3/2019  13:23  Credit card  324.31                 4.761905
# 3   1/27/2019  20:33      Ewallet  465.76                 4.761905
# ...

# %%
Female.shape
# Out:
# (501, 17)

# %%
non_Female = df[df['Gender'] != 'Female']
non_Female.head()
# Out:
#      Invoice ID Branch       City Customer type Gender  \
# 2   631-41-3108      A     Yangon        Normal   Male
# 3   123-19-1176      A     Yangon        Member   Male
# 4   373-73-7910      A     Yangon        Normal   Male
# 5   699-14-3026      C  Naypyitaw        Normal   Male
# 11  529-56-3974      B   Mandalay        Member   Male
#
#               Product line  Unit price  Quantity   Tax 5%     Total  \
# 2       Home and lifestyle       46.33         7  16.2155  340.5255
# 3        Health and beauty       58.22         8  23.2880  489.0480
# 4        Sports and travel       86.31         7  30.2085  634.3785
# 5   Electronic accessories       85.39         7  29.8865  627.6165
# 11  Electronic accessories       25.51         4   5.1020  107.1420
#
#          Date   Time      Payment    cogs  gross margin percentage  \
# 2    3/3/2019  13:23  Credit card  324.31                 4.761905
# 3   1/27/2019  20:33      Ewallet  465.76                 4.761905
# ...

# %%
long_Product_line = df[df['gross income'] > 5]
long_Product_line[['Rating','Payment']]
# Out:
#      Rating      Payment
# 0       9.1      Ewallet
# 2       7.4  Credit card
# 3       8.4      Ewallet
# 4       5.3      Ewallet
# 5       4.1      Ewallet
# ..      ...          ...
# 991     6.0      Ewallet
# 992     8.8      Ewallet
# 993     6.6      Ewallet
# 996     4.4      Ewallet
# 999     6.6         Cash
#
# [776 rows x 2 columns]

# %%
long_Product_line = df[df['gross income'] > 5]

# %%
long_Product_line.tail()
# Out:
#       Invoice ID Branch      City Customer type  Gender  \
# 991  602-16-6955      B  Mandalay        Normal  Female
# 992  745-74-0715      A    Yangon        Normal    Male
# 993  690-01-6631      B  Mandalay        Normal    Male
# 996  303-96-2227      B  Mandalay        Normal  Female
# 999  849-09-3807      A    Yangon        Member  Female
#
#                Product line  Unit price  Quantity  Tax 5%     Total  \
# 991       Sports and travel       76.60        10  38.300   804.300
# 992  Electronic accessories       58.03         2   5.803   121.863
# 993     Fashion accessories       17.49        10   8.745   183.645
# 996      Home and lifestyle       97.38        10  48.690  1022.490
# 999     Fashion accessories       88.34         7  30.919   649.299
#
#           Date   Time  Payment    cogs  gross margin percentage  gross income  \
# 991  1/24/2019  18:10  Ewallet  766.00                 4.761905        38.300
# ...

# %%
(df['Gender']=='Female') & (df['gross income'] > 10)
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996     True
# 997    False
# 998    False
# 999     True
# Length: 1000, dtype: bool

# %%
long_Product_line = df[(df['Gender']=='Female') & (df['gross income'] > 10)]
long_Product_line.head()
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 0   750-67-8428      A     Yangon        Member  Female
# 6   355-53-5943      A     Yangon        Member  Female
# 7   315-22-5665      C  Naypyitaw        Normal  Female
# 12  365-64-0515      A     Yangon        Normal  Female
# 14  829-34-3910      A     Yangon        Normal  Female
#
#               Product line  Unit price  Quantity   Tax 5%     Total  \
# 0        Health and beauty       74.69         7  26.1415  548.9715
# 6   Electronic accessories       68.84         6  20.6520  433.6920
# 7       Home and lifestyle       73.56        10  36.7800  772.3800
# 12  Electronic accessories       46.95         5  11.7375  246.4875
# 14       Health and beauty       71.38        10  35.6900  749.4900
#
#          Date   Time  Payment    cogs  gross margin percentage  gross income  \
# 0    1/5/2019  13:08  Ewallet  522.83                 4.761905       26.1415
# ...

# %%
long_Product_line.shape
# Out:
# (302, 17)

# %%
df.shape
# Out:
# (1000, 17)

# %%
df['gross income']
# Out:
# 0      26.1415
# 1       3.8200
# 2      16.2155
# 3      23.2880
# 4      30.2085
#         ...
# 995     2.0175
# 996    48.6900
# 997     1.5920
# 998     3.2910
# 999    30.9190
# Name: gross income, Length: 1000, dtype: float64

# %%
# Add new column which is just half of the runtime
df['half_gross_income'] = df['gross income'] * 0.5

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# # next we can drop some columns which we want to drop

# %%
df.drop(['Branch'], axis= 1, inplace=True)

# %%
df.head()
# Out:
#     Invoice ID       City Customer type  Gender            Product line  \
# 0  750-67-8428     Yangon        Member  Female       Health and beauty
# 1  226-31-3081  Naypyitaw        Normal  Female  Electronic accessories
# 2  631-41-3108     Yangon        Normal    Male      Home and lifestyle
# 3  123-19-1176     Yangon        Member    Male       Health and beauty
# 4  373-73-7910     Yangon        Normal    Male       Sports and travel
#
#    Unit price  Quantity   Tax 5%     Total       Date   Time      Payment  \
# 0       74.69         7  26.1415  548.9715   1/5/2019  13:08      Ewallet
# 1       15.28         5   3.8200   80.2200   3/8/2019  10:29         Cash
# 2       46.33         7  16.2155  340.5255   3/3/2019  13:23  Credit card
# 3       58.22         8  23.2880  489.0480  1/27/2019  20:33      Ewallet
# 4       86.31         7  30.2085  634.3785   2/8/2019  10:37      Ewallet
#
#      cogs  gross margin percentage  gross income  Rating  half_gross_income
# ...

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating  half_gross_income
# count             1.000000e+03   1000.000000  1000.00000        1000.000000
# mean              4.761905e+00     15.379369     6.97270           7.689685
# std               6.131498e-14     11.708825     1.71858           5.854413
# ...

# %% [markdown]
# # we can drop multiple columns at once too¶

# %%
df.drop(['half_gross_income','Rating'], axis=1,inplace=True)

# %%
df.drop(['cogs'],axis=1, inplace=True)

# %%
df.head()
# Out:
#     Invoice ID       City Customer type  Gender            Product line  \
# 0  750-67-8428     Yangon        Member  Female       Health and beauty
# 1  226-31-3081  Naypyitaw        Normal  Female  Electronic accessories
# 2  631-41-3108     Yangon        Normal    Male      Home and lifestyle
# 3  123-19-1176     Yangon        Member    Male       Health and beauty
# 4  373-73-7910     Yangon        Normal    Male       Sports and travel
#
#    Unit price  Quantity   Tax 5%     Total       Date   Time      Payment  \
# 0       74.69         7  26.1415  548.9715   1/5/2019  13:08      Ewallet
# 1       15.28         5   3.8200   80.2200   3/8/2019  10:29         Cash
# 2       46.33         7  16.2155  340.5255   3/3/2019  13:23  Credit card
# 3       58.22         8  23.2880  489.0480  1/27/2019  20:33      Ewallet
# 4       86.31         7  30.2085  634.3785   2/8/2019  10:37      Ewallet
#
#    gross margin percentage  gross income
# 0                 4.761905       26.1415
# ...

# %% [markdown]
# # Creating another new column by substracting/adding two existing column

# %%
df['Profit'] = df['Unit price'] - df['gross income']

# %%
df.head()
# Out:
#     Invoice ID       City Customer type  Gender            Product line  \
# 0  750-67-8428     Yangon        Member  Female       Health and beauty
# 1  226-31-3081  Naypyitaw        Normal  Female  Electronic accessories
# 2  631-41-3108     Yangon        Normal    Male      Home and lifestyle
# 3  123-19-1176     Yangon        Member    Male       Health and beauty
# 4  373-73-7910     Yangon        Normal    Male       Sports and travel
#
#    Unit price  Quantity   Tax 5%     Total       Date   Time      Payment  \
# 0       74.69         7  26.1415  548.9715   1/5/2019  13:08      Ewallet
# 1       15.28         5   3.8200   80.2200   3/8/2019  10:29         Cash
# 2       46.33         7  16.2155  340.5255   3/3/2019  13:23  Credit card
# 3       58.22         8  23.2880  489.0480  1/27/2019  20:33      Ewallet
# 4       86.31         7  30.2085  634.3785   2/8/2019  10:37      Ewallet
#
#    gross margin percentage  gross income   Profit
# ...

# %% [markdown]
# # We can do a lot basic operation as well

# %%
df['gross income'].sum()
# Out:
# 15379.368999999999

# %%
# what if there is a null value
df.loc[:1,'Unit price'] = np.nan

# %%
df.iloc[:5]
# Out:
#     Invoice ID       City Customer type  Gender            Product line  \
# 0  750-67-8428     Yangon        Member  Female       Health and beauty
# 1  226-31-3081  Naypyitaw        Normal  Female  Electronic accessories
# 2  631-41-3108     Yangon        Normal    Male      Home and lifestyle
# 3  123-19-1176     Yangon        Member    Male       Health and beauty
# 4  373-73-7910     Yangon        Normal    Male       Sports and travel
#
#    Unit price  Quantity   Tax 5%     Total       Date   Time      Payment  \
# 0         NaN         7  26.1415  548.9715   1/5/2019  13:08      Ewallet
# 1         NaN         5   3.8200   80.2200   3/8/2019  10:29         Cash
# 2       46.33         7  16.2155  340.5255   3/3/2019  13:23  Credit card
# 3       58.22         8  23.2880  489.0480  1/27/2019  20:33      Ewallet
# 4       86.31         7  30.2085  634.3785   2/8/2019  10:37      Ewallet
#
#    gross margin percentage  gross income   Profit
# ...

# %%
df.set_index('Invoice ID', inplace=True)

# %%
df.head()
# Out:
#                   City Customer type  Gender            Product line  \
# Invoice ID
# 750-67-8428     Yangon        Member  Female       Health and beauty
# 226-31-3081  Naypyitaw        Normal  Female  Electronic accessories
# 631-41-3108     Yangon        Normal    Male      Home and lifestyle
# 123-19-1176     Yangon        Member    Male       Health and beauty
# 373-73-7910     Yangon        Normal    Male       Sports and travel
#
#              Unit price  Quantity   Tax 5%     Total       Date   Time  \
# Invoice ID
# 750-67-8428         NaN         7  26.1415  548.9715   1/5/2019  13:08
# 226-31-3081         NaN         5   3.8200   80.2200   3/8/2019  10:29
# 631-41-3108       46.33         7  16.2155  340.5255   3/3/2019  13:23
# 123-19-1176       58.22         8  23.2880  489.0480  1/27/2019  20:33
# 373-73-7910       86.31         7  30.2085  634.3785   2/8/2019  10:37
#
#                  Payment  gross margin percentage  gross income   Profit
# Invoice ID
# ...

# %%
df.iloc[:3]
# Out:
#                   City Customer type  Gender            Product line  \
# Invoice ID
# 750-67-8428     Yangon        Member  Female       Health and beauty
# 226-31-3081  Naypyitaw        Normal  Female  Electronic accessories
# 631-41-3108     Yangon        Normal    Male      Home and lifestyle
#
#              Unit price  Quantity   Tax 5%     Total      Date   Time  \
# Invoice ID
# 750-67-8428         NaN         7  26.1415  548.9715  1/5/2019  13:08
# 226-31-3081         NaN         5   3.8200   80.2200  3/8/2019  10:29
# 631-41-3108       46.33         7  16.2155  340.5255  3/3/2019  13:23
#
#                  Payment  gross margin percentage  gross income   Profit
# Invoice ID
# 750-67-8428      Ewallet                 4.761905       26.1415  48.5485
# 226-31-3081         Cash                 4.761905        3.8200  11.4600
# 631-41-3108  Credit card                 4.761905       16.2155  30.1145

# %%
df.loc[['750-67-8428','226-31-3081']]
# Out:
#                   City Customer type  Gender            Product line  \
# Invoice ID
# 750-67-8428     Yangon        Member  Female       Health and beauty
# 226-31-3081  Naypyitaw        Normal  Female  Electronic accessories
#
#              Unit price  Quantity   Tax 5%     Total      Date   Time  \
# Invoice ID
# 750-67-8428         NaN         7  26.1415  548.9715  1/5/2019  13:08
# 226-31-3081         NaN         5   3.8200   80.2200  3/8/2019  10:29
#
#              Payment  gross margin percentage  gross income   Profit
# Invoice ID
# 750-67-8428  Ewallet                 4.761905       26.1415  48.5485
# 226-31-3081     Cash                 4.761905        3.8200  11.4600

# %%
df.head()
# Out:
#                   City Customer type  Gender            Product line  \
# Invoice ID
# 750-67-8428     Yangon        Member  Female       Health and beauty
# 226-31-3081  Naypyitaw        Normal  Female  Electronic accessories
# 631-41-3108     Yangon        Normal    Male      Home and lifestyle
# 123-19-1176     Yangon        Member    Male       Health and beauty
# 373-73-7910     Yangon        Normal    Male       Sports and travel
#
#              Unit price  Quantity   Tax 5%     Total       Date   Time  \
# Invoice ID
# 750-67-8428         NaN         7  26.1415  548.9715   1/5/2019  13:08
# 226-31-3081         NaN         5   3.8200   80.2200   3/8/2019  10:29
# 631-41-3108       46.33         7  16.2155  340.5255   3/3/2019  13:23
# 123-19-1176       58.22         8  23.2880  489.0480  1/27/2019  20:33
# 373-73-7910       86.31         7  30.2085  634.3785   2/8/2019  10:37
#
#                  Payment  gross margin percentage  gross income   Profit
# Invoice ID
# ...

# %%
df['gross income'].sum()
# Out:
# 15379.368999999999

# %%
print(f"The shortest City is {df['gross income'].min()}")
print(f"The largest City is {df['gross income'].max()}")
# Out:
# The shortest City is 0.5085
# The largest City is 49.65

# %%
df[df['gross income']==26.1415]
# Out:
#                City Customer type  Gender       Product line  Unit price  \
# Invoice ID
# 750-67-8428  Yangon        Member  Female  Health and beauty         NaN
#
#              Quantity   Tax 5%     Total      Date   Time  Payment  \
# Invoice ID
# 750-67-8428         7  26.1415  548.9715  1/5/2019  13:08  Ewallet
#
#              gross margin percentage  gross income   Profit
# Invoice ID
# 750-67-8428                 4.761905       26.1415  48.5485

# %% [markdown]
# # apply() method applies a function to every row in a pandas dataframe

# %%
def to_uppercase(column):
    return column.upper()

# %%
df['Capitalized_title'] = df['Payment'].apply(to_uppercase)

# %%
df.head()
# Out:
#                   City Customer type  Gender            Product line  \
# Invoice ID
# 750-67-8428     Yangon        Member  Female       Health and beauty
# 226-31-3081  Naypyitaw        Normal  Female  Electronic accessories
# 631-41-3108     Yangon        Normal    Male      Home and lifestyle
# 123-19-1176     Yangon        Member    Male       Health and beauty
# 373-73-7910     Yangon        Normal    Male       Sports and travel
#
#              Unit price  Quantity   Tax 5%     Total       Date   Time  \
# Invoice ID
# 750-67-8428         NaN         7  26.1415  548.9715   1/5/2019  13:08
# 226-31-3081         NaN         5   3.8200   80.2200   3/8/2019  10:29
# 631-41-3108       46.33         7  16.2155  340.5255   3/3/2019  13:23
# 123-19-1176       58.22         8  23.2880  489.0480  1/27/2019  20:33
# 373-73-7910       86.31         7  30.2085  634.3785   2/8/2019  10:37
#
#                  Payment  gross margin percentage  gross income   Profit  \
# Invoice ID
# ...

# %% [markdown]
# # Another way to usee apply() involves the use of lambda() function.
# A lambda() function is a small anonymous function.
#
# A lambda() function can take any number of arguments, but can only have one expression

# %%
def add_two_numbers(a,b):
    return a+b

# %%
x = lambda a,b:a+b
x(1,5)
# Out:
# 6

# %%
# Sort values in descending order
df.sort_values('gross income', ascending=False)
# Out:
#                   City Customer type  Gender         Product line  Unit price  \
# Invoice ID
# 860-79-0874  Naypyitaw        Member  Female  Fashion accessories       99.30
# 687-47-8271     Yangon        Normal    Male  Fashion accessories       98.98
# 283-26-5248  Naypyitaw        Member  Female   Food and beverages       98.52
# 751-41-9720  Naypyitaw        Normal    Male   Home and lifestyle       97.50
# 303-96-2227   Mandalay        Normal  Female   Home and lifestyle       97.38
# ...                ...           ...     ...                  ...         ...
# 236-86-3015  Naypyitaw        Member    Male   Home and lifestyle       13.98
# 192-98-7397  Naypyitaw        Normal    Male  Fashion accessories       12.78
# 279-62-1445  Naypyitaw        Member  Female  Fashion accessories       12.54
# 308-39-1707     Yangon        Normal  Female  Fashion accessories       12.09
# 784-21-9238  Naypyitaw        Member    Male    Sports and travel       10.17
#
# ...

# %%
# We can also sort by the combination of two columns
df.sort_values(['Tax 5%','Profit'], ascending=[False,True]).head()
# Out:
#                   City Customer type  Gender         Product line  Unit price  \
# Invoice ID
# 860-79-0874  Naypyitaw        Member  Female  Fashion accessories       99.30
# 687-47-8271     Yangon        Normal    Male  Fashion accessories       98.98
# 283-26-5248  Naypyitaw        Member  Female   Food and beverages       98.52
# 751-41-9720  Naypyitaw        Normal    Male   Home and lifestyle       97.50
# 303-96-2227   Mandalay        Normal  Female   Home and lifestyle       97.38
#
#              Quantity  Tax 5%    Total       Date   Time      Payment  \
# Invoice ID
# 860-79-0874        10   49.65  1042.65  2/15/2019  14:53  Credit card
# 687-47-8271        10   49.49  1039.29   2/8/2019  16:20  Credit card
# 283-26-5248        10   49.26  1034.46  1/30/2019  20:23      Ewallet
# 751-41-9720        10   48.75  1023.75  1/12/2019  16:18      Ewallet
# 303-96-2227        10   48.69  1022.49   3/2/2019  17:16      Ewallet
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 750-67-8428 to 849-09-3807
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   City                     1000 non-null   object
#  1   Customer type            1000 non-null   object
#  2   Gender                   1000 non-null   object
#  3   Product line             1000 non-null   object
#  4   Unit price               998 non-null    float64
#  5   Quantity                 1000 non-null   int64
#  6   Tax 5%                   1000 non-null   float64
#  7   Total                    1000 non-null   float64
#  8   Date                     1000 non-null   object
#  9   Time                     1000 non-null   object
#  10  Payment                  1000 non-null   object
#  11  gross margin percentage  1000 non-null   float64
#  12  gross income             1000 non-null   float64
# ...

# %% [markdown]
# # strptime means string parser, this will convert a string format to datetime
# # strftime means string formatters, this will format a datetime object to string format

# %%
# importing datetime module
from datetime import datetime
from datetime import date

# %%
df['Date'][0:5]
# Out:
# Invoice ID
# 750-67-8428     1/5/2019
# 226-31-3081     3/8/2019
# 631-41-3108     3/3/2019
# 123-19-1176    1/27/2019
# 373-73-7910     2/8/2019
# Name: Date, dtype: object

# %%
df['Date']=df['new_time'].apply(lambda x : datetime.strptime(x,'%m/%d/%y'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# E:\New folder (3)\Jupitor\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# E:\New folder (3)\Jupitor\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# E:\New folder (3)\Jupitor\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'new_time'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.info()

# %%
df.head()

# %%
df['Date'][0]

# %%
print(Date.today())
print(Datetime.now())

# %%
date.now()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8336\2801338866.py in <module>
# ----> 1 date.now()
#
# AttributeError: type object 'datetime.date' has no attribute 'now'

# %% [markdown]
# # lets explore unique and missing values
# unique()
#
# nunique()
#
# value_counts()
#
# isnull()
#
# fillna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 750-67-8428 to 849-09-3807
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   City                     1000 non-null   object
#  1   Customer type            1000 non-null   object
#  2   Gender                   1000 non-null   object
#  3   Product line             1000 non-null   object
#  4   Unit price               998 non-null    float64
#  5   Quantity                 1000 non-null   int64
#  6   Tax 5%                   1000 non-null   float64
#  7   Total                    1000 non-null   float64
#  8   Date                     1000 non-null   object
#  9   Time                     1000 non-null   object
#  10  Payment                  1000 non-null   object
#  11  gross margin percentage  1000 non-null   float64
#  12  gross income             1000 non-null   float64
# ...

# %%
# Find the list of unique values in a column
list(df['Capitalized_title'].unique())
# Out:
# ['EWALLET', 'CASH', 'CREDIT CARD']

# %%
list(df['Gender'].unique())
# Out:
# ['Female', 'Male']

# %%
# Counts the number of unique values in a column
df.Gender.nunique()
# Out:
# 2

# %%
# Give the counts of each category of a variable
df['Gender'].value_counts()
# Out:
# Female    501
# Male      499
# Name: Gender, dtype: int64

# %%
df['Customer type'].isnull()
# Out:
# Invoice ID
# 750-67-8428    False
# 226-31-3081    False
# 631-41-3108    False
# 123-19-1176    False
# 373-73-7910    False
#                ...
# 233-67-5758    False
# 303-96-2227    False
# 727-02-1313    False
# 347-56-2442    False
# 849-09-3807    False
# Name: Customer type, Length: 1000, dtype: bool

# %%
df[~df['Customer type'].isnull()]
# Out:
#                   City Customer type  Gender            Product line  \
# Invoice ID
# 750-67-8428     Yangon        Member  Female       Health and beauty
# 226-31-3081  Naypyitaw        Normal  Female  Electronic accessories
# 631-41-3108     Yangon        Normal    Male      Home and lifestyle
# 123-19-1176     Yangon        Member    Male       Health and beauty
# 373-73-7910     Yangon        Normal    Male       Sports and travel
# ...                ...           ...     ...                     ...
# 233-67-5758  Naypyitaw        Normal    Male       Health and beauty
# 303-96-2227   Mandalay        Normal  Female      Home and lifestyle
# 727-02-1313     Yangon        Member    Male      Food and beverages
# 347-56-2442     Yangon        Normal    Male      Home and lifestyle
# 849-09-3807     Yangon        Member  Female     Fashion accessories
#
#              Unit price  Quantity   Tax 5%      Total       Date   Time  \
# Invoice ID
# ...

# %%
df['Customer type'].fillna('Not Present',inplace= True)

# %%
df.head()
# Out:
#                   City Customer type  Gender            Product line  \
# Invoice ID
# 750-67-8428     Yangon        Member  Female       Health and beauty
# 226-31-3081  Naypyitaw        Normal  Female  Electronic accessories
# 631-41-3108     Yangon        Normal    Male      Home and lifestyle
# 123-19-1176     Yangon        Member    Male       Health and beauty
# 373-73-7910     Yangon        Normal    Male       Sports and travel
#
#              Unit price  Quantity   Tax 5%     Total       Date   Time  \
# Invoice ID
# 750-67-8428         NaN         7  26.1415  548.9715   1/5/2019  13:08
# 226-31-3081         NaN         5   3.8200   80.2200   3/8/2019  10:29
# 631-41-3108       46.33         7  16.2155  340.5255   3/3/2019  13:23
# 123-19-1176       58.22         8  23.2880  489.0480  1/27/2019  20:33
# 373-73-7910       86.31         7  30.2085  634.3785   2/8/2019  10:37
#
#                  Payment  gross margin percentage  gross income   Profit  \
# Invoice ID
# ...

# %% [markdown]
# # Data Wrangling

# %%
import pandas as pd
import numpy as np

# %%
pwd
# Out:
# 'C:\\Users\\DELL\\Python INFOTECH'

# %%
imdb_df=pd.read_csv("Supermarket_Sales.csv")

# %%
imdb_df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
imdb_df.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675  1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320   2/9/2019  13:22     Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  15:33     Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  13:28     Cash
#
# ...

# %% [markdown]
# # Let us go ahead and create three subsets of our original dataset

# %%
# Create three dataframes
imdb1 = imdb_df[imdb_df['gross income']>=2]
imdb2 = imdb_df[ (imdb_df['gross income']<5) & (imdb_df['gross income']>100 )]
imdb3 = imdb_df[imdb_df['gross income']<=8]

# %%
imdb1.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
imdb2.head()
# Out:
# Empty DataFrame
# Columns: [Invoice ID, Branch, City, Customer type, Gender, Product line, Unit price, Quantity, Tax 5%, Total, Date, Time, Payment, cogs, gross margin percentage, gross income, Rating]
# Index: []

# %%
imdb3.head()
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 1   226-31-3081      C  Naypyitaw        Normal  Female
# 8   665-32-9167      A     Yangon        Member  Female
# 10  351-62-0822      B   Mandalay        Member  Female
# 11  529-56-3974      B   Mandalay        Member    Male
# 19  319-50-3348      B   Mandalay        Normal  Female
#
#               Product line  Unit price  Quantity  Tax 5%    Total       Date  \
# 1   Electronic accessories       15.28         5   3.820   80.220   3/8/2019
# 8        Health and beauty       36.26         2   3.626   76.146  1/10/2019
# 10     Fashion accessories       14.48         4   2.896   60.816   2/6/2019
# 11  Electronic accessories       25.51         4   5.102  107.142   3/9/2019
# 19      Home and lifestyle       40.30         2   4.030   84.630  3/11/2019
#
#      Time      Payment    cogs  gross margin percentage  gross income  Rating
# 1   10:29         Cash   76.40                 4.761905         3.820     9.6
# ...

# %%
# concate both axis
imdb_non_null_gross income = pd.concat([imdb1,imdb2,imdb3])
imdb_non_null_gross income
# Out:
#   File "C:\Users\DELL\AppData\Local\Temp\ipykernel_8336\1651712939.py", line 2
#     imdb_non_null_gross income = pd.concat([imdb1,imdb2,imdb3])
#                         ^
# SyntaxError: invalid syntax

# %%
imdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
imdb_df.shape
# Out:
# (1000, 17)

# %%
imdb1.shape,imdb2.shape,imdb3.shape
# Out:
# ((946, 17), (0, 17), (345, 17))

# %%
# Concatenate a long a perticul an axis

sample_df = pd.concat([imdb1, imdb2],axis=1)

# %%
sample_df.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price Quantity   Tax 5%      Total  ...  \
# 994  Electronic accessories       60.95        1   3.0475    63.9975  ...
# 995       Health and beauty       40.35        1   2.0175    42.3675  ...
# 996      Home and lifestyle       97.38       10  48.6900  1022.4900  ...
# 998      Home and lifestyle       65.82        1   3.2910    69.1110  ...
# 999     Fashion accessories       88.34        7  30.9190   649.2990  ...
#
#     Quantity Tax 5% Total  Date  Time  Payment  cogs gross margin percentage  \
# 994      NaN    NaN   NaN   NaN   NaN      NaN   NaN                     NaN
# ...

# %%
sample_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 946 entries, 0 to 999
# Data columns (total 34 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               946 non-null    object
#  1   Branch                   946 non-null    object
#  2   City                     946 non-null    object
#  3   Customer type            946 non-null    object
#  4   Gender                   946 non-null    object
#  5   Product line             946 non-null    object
#  6   Unit price               946 non-null    float64
#  7   Quantity                 946 non-null    int64
#  8   Tax 5%                   946 non-null    float64
#  9   Total                    946 non-null    float64
#  10  Date                     946 non-null    object
#  11  Time                     946 non-null    object
#  12  Payment                  946 non-null    object
#  13  cogs                     946 non-null    float64
# ...

# %%
sample_df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating', 'Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
imdb1.shape, imdb2.shape
# Out:
# ((946, 17), (0, 17))
